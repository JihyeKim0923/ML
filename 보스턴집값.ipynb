# %%
# 라이브러리
import tensorflow as tf
import pandas as pd

# %%
# 데이터 가져오기
file='https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
data=pd.read_csv(file)
print(data.columns)
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
# 종속변수, 독립변수 나누기
종속= data[['medv']]
독립= data[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
            'ptratio', 'b', 'lstat']]

print(종속.shape, 독립.shape)
# Out:
# (506, 1) (506, 13)

# %%
# 모델 구조 만들기
X= tf.keras.layers.Input(shape=[13])
Y= tf.keras.layers.Dense(1)(X)
model=tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
# 모델 학습
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.7458
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.5302
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.1286
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.6137
# Epoch 5/10
# 16/16 [==============================] - 0s 973us/step - loss: 23.8682
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 23.5561
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.5973
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.6653
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.8447
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.1669

# %%
# 모델 사용
model.predict(독립[0:5]) # 독립변수 5행만 사용
# Out:
# array([[30.285091],
#        [25.10113 ],
#        [31.5733  ],
#        [30.156582],
#        [29.770042]], dtype=float32)

# %%
종속[0:5] # 실제 값과 비교해보기
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
# 모델의 수식 확인
model.get_weights() # 가중치
# Out:
# [array([[-0.09398911],
#         [ 0.04820454],
#         [-0.02079994],
#         [ 2.6567905 ],
#         [-2.6174903 ],
#         [ 5.213212  ],
#         [-0.0098998 ],
#         [-1.077861  ],
#         [ 0.20360334],
#         [-0.01005212],
#         [-0.53158754],
#         [ 0.01402348],
#         [-0.4638224 ]], dtype=float32), array([9.30034], dtype=float32)]

# %% [markdown]
# 각 변수의 가중치.
# array의 값 9.30034가 편향.
