# %%
# 라이브러리
import pandas as pd
import tensorflow as tf

# %%
# 데이터 준비
file='https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
data= pd.read_csv(file)
data.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
# 종속변수, 독립변수
독립=data[['온도']]
종속=data[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
# 모델을 만든다.
X= tf.keras.layers.Input(shape=[1])
Y= tf.keras.layers.Dense(1)(X)

model=tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
# 모델을 학습시킨다.
model.fit(독립, 종속, epochs=1000, verbose=0) # verbose는 출력화면 개수를 조절
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 3ms/step - loss: 4.2392e-04
# Epoch 2/10
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2354e-04
# Epoch 3/10
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2326e-04
# Epoch 4/10
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2306e-04
# Epoch 5/10
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2295e-04
# Epoch 6/10
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2281e-04
# Epoch 7/10
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2268e-04
# Epoch 8/10
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2260e-04
# Epoch 9/10
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2234e-04
# Epoch 10/10
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2207e-04

# %%
# 모델을 이용
model.predict(독립)
# Out:
# array([[40.036278],
#        [42.026955],
#        [44.01763 ],
#        [46.008312],
#        [47.99899 ],
#        [49.989666]], dtype=float32)

# %%
model.predict([[15]])
# Out:
# array([[30.082884]], dtype=float32)
